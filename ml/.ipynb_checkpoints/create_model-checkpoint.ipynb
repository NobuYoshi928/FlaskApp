# %%
import os
import pickle
import warnings

import pandas as pd
import psycopg2

from utils import ml_workflow, db

warnings.filterwarnings("ignore")

# %%
conn, _ = db.connect('dev')
src_df = pd.read_sql(sql="SELECT * FROM diabetes_diagnosis_results;", con=conn)

# %%
src_df.columns

# %%
src_df.head()
# Out:
#    index  pregnancies  glucose  blood_pressure  skin_thickness  insulin  \
# 0    200            9      125              74             0.0      0.0
# 1   3832            4      109              80             0.0      0.0
# 2   4927            4       88              78            39.0      0.0
# 3   4088            9      125              74             0.0      0.0
# 4   3644            5      107              78            44.0    284.0
#
#          bmi  diabetes_pedigree_function  age  outcome  is_trained
# 0  28.536910                    0.444902   45        1        True
# 1  28.047673                    0.238243   22        0        True
# 2  52.371341                    0.279471   26        0        True
# 3  40.062688                    0.203922   45        0        True
# 4  52.935068                    0.284959   45        1        True

# %%
src_df['is_trained'].value_counts()
# Out:
# False    1001
# True     1000
# Name: is_trained, dtype: int64

# %%
df = src_df.drop("is_trained", axis=1, inplace=False)
df.head()
# Out:
#    index  pregnancies  glucose  blood_pressure  skin_thickness  insulin  \
# 0    200            9      125              74             0.0      0.0
# 1   3832            4      109              80             0.0      0.0
# 2   4927            4       88              78            39.0      0.0
# 3   4088            9      125              74             0.0      0.0
# 4   3644            5      107              78            44.0    284.0
#
#          bmi  diabetes_pedigree_function  age  outcome
# 0  28.536910                    0.444902   45        1
# 1  28.047673                    0.238243   22        0
# 2  52.371341                    0.279471   26        0
# 3  40.062688                    0.203922   45        0
# 4  52.935068                    0.284959   45        1

# %%
C = 0.1
ml_workflow.train_and_evaluate_model(df, C)
# Out:
# ID: 20220110114144, C: 0.1, AUC score: 0.7334239834239835

# %%
C = 0.5
ml_workflow.train_and_evaluate_model(df, C)
# Out:
# ID: 20220110114147, C: 0.5, AUC score: 0.7668026418026417

# %%
C = 1.0
ml_workflow.train_and_evaluate_model(df, C)
# Out:
# ID: 20220110114148, C: 1.0, AUC score: 0.7777777777777778

# %%
C = 5.0
ml_workflow.train_and_evaluate_model(df, C)
# Out:
# ID: 20220110115017, C: 5.0, AUC score: 0.7887529137529137

# %%
C = 10.0
ml_workflow.train_and_evaluate_model(df, C)

# %%
run_id=20220110115017
C=5.0
ml_workflow.train_and_deploy_model(run_id, C)
# Out:
# deploy finished

# %%
input_dict = {
    "index": [1],
    "pregnancies": [1],
    "glucose": [1],
    "bloodpressure": [1],
    "skinthickness": [1],
    "insulin": [1],
    "bmi": [1],
    "diabetespedigreefunction": [1],
    "age": [1],
}
input_df = pd.DataFrame(input_dict)

# %%
imputer = pickle.load(open(f"./deploy/20220109103554/models/imputer.pkl", "rb"))
model = pickle.load(open(f"./deploy/20220109103554/models/mlmodel.pkl", "rb"))
input_y_proba, input_y_pred = ml_workflow.predict(input_df, imputer, model)

# %%
input_y_proba[0]
# Out:
# 0.0025069771694962396

# %%
input_y_pred[0]
# Out:
# 0

# %%
with open('./deploy/20220110115017/train_indexes.txt', mode='r') as f:
    text = f.readlines()[0]
    print(text.split(','))
# Out:
# ['200', '3832', '4927', '4088', '3644', '3323', '2203', '565', '1386', '4162', '4818', '1744', '426', '2340', '3485', '4710', '929', '2498', '3260', '4294', '4755', '4549', '1240', '3649', '4647', '2404', '1287', '2804', '1574', '1989', '2955', '1373', '959', '1768', '71', '390', '3385', '2696', '1334', '169', '743', '2830', '2066', '951', '4849', '190', '4699', '1342', '1895', '97', '2047', '2425', '1183', '3931', '4434', '1577', '4805', '4589', '4798', '1093', '4117', '316', '2396', '132', '1770', '1494', '3949', '1667', '299', '616', '2300', '4133', '1059', '3448', '2509', '4538', '2242', '3882', '703', '1128', '2194', '3636', '4597', '414', '3495', '211', '3998', '3030', '4082', '4497', '1646', '940', '4980', '3844', '713', '1078', '4206', '3694', '1955', '2528', '779', '796', '3210', '4508', '2385', '936', '351', '3768', '1733', '365', '2244', '3314', '4990', '1015', '1081', '2355', '2481', '744', '686', '963', '677', '3916', '3509', '1719', '2855', '1235', '3666', '4437', '2141', '3422', '4632', '1236', '1037', '4325', '2623', '3391', '3534', '458', '3379', '955', '924', '3817', '2440', '574', '3452', '719', '1195', '1074', '4412', '4855', '3990', '4022', '3039', '1553', '3827', '3040', '1032', '1856', '3977', '547', '793', '1501', '1572', '3442', '330', '4637', '2579', '1713', '4442', '2747', '2882', '710', '3036', '1101', '4861', '4017', '356', '3456', '493', '3813', '69', '1313', '4337', '4766', '1618', '3079', '1535', '175', '981', '4274', '826', '1254', '3244', '2010', '2401', '3076', '764', '4800', '1600', '2', '800', '786', '2961', '4919', '674', '2720', '2706', '4255', '2534', '238', '427', '2423', '204', '923', '240', '2443', '1927', '3471', '670', '3397', '4354', '694', '1023', '3439', '3080', '1044', '366', '4758', '1140', '3880', '259', '3074', '3546', '3875', '1214', '163', '4831', '1583', '264', '385', '1943', '3556', '3255', '4987', '701', '4488', '3675', '272', '2734', '3540', '1395', '277', '1151', '3668', '1886', '1446', '4489', '4306', '3031', '2143', '1094', '4184', '4498', '2868', '964', '4127', '179', '3044', '4382', '2594', '4541', '1952', '2157', '105', '999', '488', '1341', '3885', '2041', '2139', '3111', '4310', '2019', '4153', '3787', '1602', '1157', '4364', '1052', '1149', '1762', '2735', '3900', '1994', '3207', '1225', '68', '2042', '1555', '4340', '1660', '2464', '1548', '4601', '975', '76', '2525', '1560', '3581', '4876', '2004', '4684', '1899', '2518', '2552', '1948', '1255', '1728', '2436', '3043', '2057', '3601', '1911', '3894', '618', '1310', '4158', '2117', '4027', '4745', '3512', '4893', '846', '4465', '4621', '300', '4542', '1732', '51', '3145', '874', '2299', '2478', '4884', '2110', '3786', '4059', '2580', '2663', '3941', '1898', '1079', '850', '228', '2085', '4769', '3227', '4959', '2996', '1914', '1699', '1048', '235', '1751', '3718', '2039', '1347', '1811', '297', '2399', '4063', '2185', '2421', '353', '3352', '1775', '3896', '856', '1917', '2835', '3915', '4516', '1554', '2540', '2471', '3122', '972', '419', '411', '2384', '2258', '2101', '4799', '4897', '791', '1317', '1693', '1647', '657', '2031', '4462', '4868', '313', '943', '3856', '1656', '4397', '1036', '1703', '503', '320', '4706', '2174', '1311', '954', '4552', '2484', '4275', '2146', '4886', '40', '1832', '4730', '4034', '2161', '454', '4824', '722', '4308', '2155', '2943', '3542', '4996', '4558', '3325', '681', '1100', '4675', '702', '1825', '1397', '4772', '1112', '652', '4270', '4453', '1110', '3790', '4048', '3427', '529', '3126', '4290', '1388', '413', '937', '1184', '3120', '3669', '3284', '1860', '3462', '711', '3653', '2857', '3750', '3884', '1945', '564', '4514', '2092', '746', '4804', '655', '2806', '323', '4278', '4839', '2899', '1137', '2784', '425', '2578', '4335', '1947', '4296', '3614', '3652', '600', '1798', '4821', '3855', '4428', '1038', '783', '1268', '4794', '3869', '2651', '121', '778', '984', '3713', '3160', '745', '4873', '2916', '1764', '3732', '2895', '1171', '2969', '1425', '176', '2843', '276 ...
